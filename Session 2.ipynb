# %% [raw]
# conditional statement (==, <, >, <=, >=,!=)

# %%
x = 8
if x < 9:
    print('True')
else:
    print('False')
# Out:
# True

# %%
x = 8
if x > 9:
    print('True')
else:
    print('False')
# Out:
# False

# %%
y = 12
if y == 2:
    print('True')
elif y <= 13:
    print(' yes y is less than 13')
else:
    print('try again')
# Out:
#  yes y is less than 13

# %%
age = int(input('Enter your age: '))
nationality = input('Enter your nationality: ')
if age >= 18 and nationality == 'pakistani':
    print('you are allowed to vote')
elif age >= 18 and nationality != 'pakistani':
    print('you are not citizen of Pakistan')
else:
    print('you are under age')
# Out:
# Enter your age:  18
# Enter your nationality:  paistani
# you are not citizen of Pakistan

# %%
salary = int(input('enter your salary'))
exp = int(input('enter your experience'))
if salary >= 20000 or exp <= 10:
    print('you are eligible')
elif salary <= 20000 or exp >= 10:
    print('you are eligible as well')
else:
    print('you are not meet with the required criteria')
# Out:
# enter your salary 55
# enter your experience 55
# you are eligible as well

# %% [markdown]
# ## Grading App

# %%
math = int(input('enter your marks :'))
eng = int(input('enter your marks :'))
phy = int(input('enter your marks :'))
chem = int(input('enter your marks :'))
pst = int(input('enter your marks :'))
total = math + eng + phy + chem + pst
percent = (total/ 500)*100
print(percent)
if percent >= 90 and percent <= 100:
    print('your grade is A+')
elif percent >= 80 and percent < 90:
    print('your grade is A')
elif percent >= 70 and percent < 80:
    print('your grade is B')
elif percent >= 60 and percent < 70:
    print('your grade is C')
elif percent >= 50 and percent < 60:
    print('your grade is D')
else:
    print('you are fail')
# Out:
# enter your marks : 76
# enter your marks : 56
# enter your marks : 68
# enter your marks : 98
# enter your marks : 45
# 68.60000000000001
# your grade is C

# %%
colors = ['red', 'green', 'black', 'white']
print(colors[2])
# Out:
# black

# %%
colors[0]
# Out:
# 'red'

# %%
colors[5]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 colors[5]
#
# IndexError: list index out of range

# %%
colors
# Out:
# ['red', 'green', 'black', 'white']

# %%
colors[1:3]
# Out:
# ['green', 'black']

# %%
colors[::1]
# Out:
# ['red', 'green', 'black', 'white']

# %%
colors[::2]
# Out:
# ['red', 'black']

# %%
colors[-4:-1:2]
# Out:
# ['red', 'black']

# %%
dir ([])
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']

# %%
colors.insert(1, 'yellow')

# %%
colors
# Out:
# ['red', 'yellow', 'green', 'black', 'white']

# %%
colors.index('red')
# Out:
# 0

# %%
colors.pop(2)
# Out:
# 'green'

# %%
colors
# Out:
# ['red', 'yellow', 'black', 'white']

# %%
colors.remove("red")

# %%
colors
# Out:
# ['yellow', 'black', 'white']

# %%
numbers = [1, 55, 3, 4.5, 77, 2]

# %%
numbers.sort()

# %%
numbers
# Out:
# [1, 2, 3, 4.5, 55, 77]

# %%
colors.sort()

# %%
colors
# Out:
# ['black', 'white', 'yellow']

# %%
num = [1,1,1, 2, 2, 3]

# %%
num.count(1)
# Out:
# 3

# %%
num.index(1)
# Out:
# 0
