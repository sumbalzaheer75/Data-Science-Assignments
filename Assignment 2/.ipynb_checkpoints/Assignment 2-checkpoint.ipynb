# %% [markdown]
# # Assignment 2

# %% [markdown]
# ### Q1. Load the dataset and display first 5 rows?

# %%
import pandas as pd
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("Sumbal Shaikh - content_based_recommendation_dataset.csv")

# %%
df.head()
# Out:
#    Number of clicks on similar products  \
# 0                                    12
# 1                                     8
# 2                                    25
# 3                                     6
# 4                                    18
#
#    Number of similar products purchased so far  \
# 0                                            4
# 1                                            2
# 2                                           10
# 3                                            1
# 4                                            5
#
#    Average rating given to similar products  Gender  \
# 0                                       4.2    male
# 1                                       3.8  female
# 2                                       4.5  female
# 3                                       2.1  female
# 4                                       4.7    male
#
#    Median purchasing price (in rupees)  Rating of the product  \
# ...

# %% [markdown]
# ### Q2. Display dataset shape and column names?

# %%
df.shape
# Out:
# (1474, 13)

# %%
df.columns
# Out:
# Index(['Number of clicks on similar products',
#        'Number of similar products purchased so far',
#        'Average rating given to similar products', 'Gender',
#        'Median purchasing price (in rupees)', 'Rating of the product',
#        'Brand of the product', 'Customer review sentiment score (overall)',
#        'Price of the product', 'Holiday', 'Season', 'Geographical locations',
#        'Probability for the product to be recommended to the person'],
#       dtype='object')

# %% [markdown]
# ### Q3. Check data types of all columns?

# %%
df.dtypes
# Out:
# Number of clicks on similar products                             int64
# Number of similar products purchased so far                      int64
# Average rating given to similar products                       float64
# Gender                                                          object
# Median purchasing price (in rupees)                              int64
# Rating of the product                                          float64
# Brand of the product                                            object
# Customer review sentiment score (overall)                      float64
# Price of the product                                             int64
# Holiday                                                         object
# Season                                                          object
# Geographical locations                                          object
# Probability for the product to be recommended to the person    float64
# dtype: object

# %% [markdown]
# ### Q4. Identify missing values in each column?

# %%
df.isnull().sum()
# Out:
# Number of clicks on similar products                           0
# Number of similar products purchased so far                    0
# Average rating given to similar products                       0
# Gender                                                         0
# Median purchasing price (in rupees)                            0
# Rating of the product                                          0
# Brand of the product                                           0
# Customer review sentiment score (overall)                      0
# Price of the product                                           0
# Holiday                                                        0
# Season                                                         0
# Geographical locations                                         0
# Probability for the product to be recommended to the person    0
# dtype: int64

# %% [markdown]
# ### Q5. Handle missing values?

# %% [markdown]
# #### After checking missing values, it was observed that all columns contain 0 missing values.
# #### Therefore, no imputation or removal was required.

# %% [markdown]
# ### Q6. Check and remove duplicate rows?

# %%
df.duplicated().sum()
# Out:
# np.int64(456)

# %%
df = df.drop_duplicates()

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ### Q7. Generate summary statistics?

# %%
df.describe()
# Out:
#        Number of clicks on similar products  \
# count                           1018.000000
# mean                              21.397839
# std                               12.103449
# min                                0.000000
# 25%                               11.000000
# 50%                               20.000000
# 75%                               31.000000
# max                               55.000000
#
#        Number of similar products purchased so far  \
# count                                  1018.000000
# mean                                      9.017682
# std                                       5.740169
# min                                       0.000000
# 25%                                       4.000000
# 50%                                       8.000000
# 75%                                      14.000000
# max                                      24.000000
#
#        Average rating given to similar products  \
# ...

# %%
df.describe(include = 'all')
# Out:
#         Number of clicks on similar products  \
# count                            1018.000000
# unique                                   NaN
# top                                      NaN
# freq                                     NaN
# mean                               21.397839
# std                                12.103449
# min                                 0.000000
# 25%                                11.000000
# 50%                                20.000000
# 75%                                31.000000
# max                                55.000000
#
#         Number of similar products purchased so far  \
# count                                   1018.000000
# unique                                          NaN
# top                                             NaN
# freq                                            NaN
# mean                                       9.017682
# std                                        5.740169
# ...

# %% [markdown]
# ### Q8. Calculate the average of 'Price of the product'?

# %%
df['Price of the product'].mean().round(2)
# Out:
# np.float64(1334.92)

# %% [markdown]
# ##### The average price of the product is 1334.92 rupees.

# %% [markdown]
# ### Q9. Find max and min of 'Median purchasing price (in rupees)'?

# %%
df['Median purchasing price (in rupees)'].max()
# Out:
# 19000

# %%
df['Median purchasing price (in rupees)'].min()
# Out:
# 100

# %% [markdown]
# ##### The maximum median purchasing price is 19000 rupees, and the minimum median purchasing price is 100 rupees.

# %% [markdown]
# ### Q10. Value counts of 'Brand of the product'?

# %%
df['Brand of the product'].value_counts()
# Out:
# Brand of the product
# Wildcraft                          74
# Manyavar Mohey                     58
# Pepperfry                          55
# Flying Machine                     52
# Patanjali Ayurved (Health Care)    50
# Lee                                46
# Lakme Ayurveda                     45
# Wakefit                            41
# Johnson & Johnson                  40
# Khadi Essentials                   34
# Pepe Jeans London                  33
# Kama Ayurveda                      32
# Max                                29
# PUMA                               25
# Head Hunters                       24
# Himalaya Liv.52                    24
# Sugar Cosmetics                    24
# Fastrack                           22
# The Moms Co.                       22
# Dettol                             21
# Urban Ladder                       20
# SleepyCat                          20
# AmazonBasics                       17
# Allen Solly Woman                  16
# ...

# %% [markdown]
# ### Q11. Sort data by 'Price of the product'?

# %%
df.sort_values(by='Price of the product', ascending=False)
# Out:
#       Number of clicks on similar products  \
# 920                                     47
# 1404                                    20
# 1431                                    17
# 851                                     45
# 1444                                    14
# ...                                    ...
# 37                                      18
# 84                                      10
# 764                                     39
# 788                                     34
# 752                                     40
#
#       Number of similar products purchased so far  \
# 920                                            20
# 1404                                            7
# 1431                                            6
# 851                                            18
# 1444                                            5
# ...                                           ...
# 37                                              8
# ...

# %% [markdown]
# ### Q12. Filter data where rating > 4?

# %%
df[df['Rating of the product'] > 4]
# Out:
#       Number of clicks on similar products  \
# 0                                       12
# 2                                       25
# 4                                       18
# 6                                       38
# 9                                       10
# ...                                    ...
# 1467                                    43
# 1468                                    21
# 1470                                    37
# 1471                                    22
# 1472                                    40
#
#       Number of similar products purchased so far  \
# 0                                               4
# 2                                              10
# 4                                               5
# 6                                              15
# 9                                               4
# ...                                           ...
# 1467                                           14
# ...

# %% [markdown]
# ### Q13. Create new column 'Price Difference'?
# ### By using (Price of the product - Median Purchasing Price)

# %%
df['Price Difference'] = df['Price of the product'] - df['Median purchasing price (in rupees)']
df.head()
# Out:
#    Number of clicks on similar products  \
# 0                                    12
# 1                                     8
# 2                                    25
# 3                                     6
# 4                                    18
#
#    Number of similar products purchased so far  \
# 0                                            4
# 1                                            2
# 2                                           10
# 3                                            1
# 4                                            5
#
#    Average rating given to similar products  Gender  \
# 0                                       4.2    male
# 1                                       3.8  female
# 2                                       4.5  female
# 3                                       2.1  female
# 4                                       4.7    male
#
#    Median purchasing price (in rupees)  Rating of the product  \
# ...

# %% [markdown]
# ### Q14. GroupBy average price by Gender?

# %%
df.groupby('Gender')['Price of the product'].mean()
# Out:
# Gender
# female     783.638171
# male      1873.359223
# Name: Price of the product, dtype: float64

# %% [markdown]
# ### Q15. Create histogram Price of the product?

# %%
plt.hist(df['Price of the product'])
plt.title("Price Distribution")
plt.xlabel("Price")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# ## Conclusion

# %% [markdown]
# ### The analysis shows that product rating and customer review sentiment have the strongest influence on product recommendations.
# ### Higher ratings and positive sentiment scores increase the probability of a product being recommended.
# ### After cleaning the data, the dataset became more reliable as duplicate entries were removed, improving accuracy.
# ### An interesting pattern observed is that even moderately priced products can have high recommendation probability if their ratings are good.
# ### Overall, customer feedback plays a key role in influencing purchasing decisions.
